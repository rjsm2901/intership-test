# %%
import pandas as pd
import numpy as np

# %%
USA=pd.read_csv('filterCountry.csv')

# %%
USA.head(10)
# Out:
#    Unnamed: 0    SKU                              DESCRIPTION  YEAR CAPACITY  \
# 0           2  11331                   Barbaresco,Angelo Gaja  1990    750ml
# 1           6  11332                   Barbaresco,Angelo Gaja  2010    750ml
# 2          18  11333       Barbaresco,Costa Russi,Angelo Gaja  2009    750ml
# 3          22  11333       Barbaresco,Costa Russi,Angelo Gaja  2009    750ml
# 4          23  11333       Barbaresco,Costa Russi,Angelo Gaja  2009    750ml
# 5          24  11333       Barbaresco,Costa Russi,Angelo Gaja  2009    750ml
# 6          28  11333       Barbaresco,Costa Russi,Angelo Gaja  2009    750ml
# 7          32  11333       Barbaresco,Costa Russi,Angelo Gaja  2009    750ml
# 8          36  11334  Barbaresco,Sori San Lorenzo,Angelo Gaja  2000    750ml
# 9          37  11334  Barbaresco,Sori San Lorenzo,Angelo Gaja  2000    750ml
#
#                                                  URL     PRICE  \
# ...

# %%
Price_filter=USA[['SKU','PRICE']]

# %%
Price_filter.head(5)
# Out:
#      SKU    PRICE
# 0  11331  $329.00
# 1  11332  $175.00
# 2  11333  $304.00
# 3  11333  $359.99
# 4  11333  $379.00

# %%
Price_filter['PRICE']=pd.to_numeric(Price_filter['PRICE'], errors='coerce')
# Out:
# C:\Users\Shivam\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
print(Price_filter.dtypes)
# Out:
# SKU        int64
# PRICE    float64
# dtype: object

# %%
Price_filter['PRICE']=Price_filter.PRICE.apply(lambda x:x.strip('$'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-79-3fc4f02307c5> in <module>
# ----> 1 Price_filter['PRICE']=Price_filter.PRICE.apply(lambda x:x.strip('$'))
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3589             else:
#    3590                 values = self.astype(object).values
# -> 3591                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3592
#    3593         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-79-3fc4f02307c5> in <lambda>(x)
# ----> 1 Price_filter['PRICE']=Price_filter.PRICE.apply(lambda x:x.strip('$'))
#
# AttributeError: 'float' object has no attribute 'strip'
