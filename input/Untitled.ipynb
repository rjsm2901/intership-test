# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('main.csv')

# %%
df.head()
# Out:
#      SKU             DESCRIPTION  YEAR CAPACITY  \
# 0  11331  Barbaresco,Angelo Gaja  1990    750ml
# 1  11331  Barbaresco,Angelo Gaja  1990    750ml
# 2  11331  Barbaresco,Angelo Gaja  1990    750ml
# 3  11331  Barbaresco,Angelo Gaja  1990    750ml
# 4  11331  Barbaresco,Angelo Gaja  1990    750ml
#
#                                                  URL    PRICE  \
# 0  https://www.wine-searcher.com/find/barbaresco+...  $295.00
# 1  https://www.wine-searcher.com/find/barbaresco+...  $324.62
# 2  https://www.wine-searcher.com/find/barbaresco+...  $329.00
# 3  https://www.wine-searcher.com/find/barbaresco+...  $338.68
# 4  https://www.wine-searcher.com/find/barbaresco+...  $396.83
#
#          SELLER_INFORMATION                    OFFER_DESCRIPTION      COUNTRY
# 0   TopWines Switzerland SA           1990Barbaresco Gaja Angelo  Switzerland
# 1         Vintage Grand Cru                  Gaja Barbaresco1990    Hong Kong
# ...

# %%
Country_USA=df.COUNTRY.str.contains('USA')

# %%
Country_USA.head()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# Name: COUNTRY, dtype: bool

# %%
USA=df[Country_USA]

# %%
print(USA.shape)
# Out:
# (3030, 9)

# %%
USA.head()
# Out:
#       SKU                         DESCRIPTION  YEAR CAPACITY  \
# 2   11331              Barbaresco,Angelo Gaja  1990    750ml
# 6   11332              Barbaresco,Angelo Gaja  2010    750ml
# 18  11333  Barbaresco,Costa Russi,Angelo Gaja  2009    750ml
# 22  11333  Barbaresco,Costa Russi,Angelo Gaja  2009    750ml
# 23  11333  Barbaresco,Costa Russi,Angelo Gaja  2009    750ml
#
#                                                   URL    PRICE  \
# 2   https://www.wine-searcher.com/find/barbaresco+...  $329.00
# 6   https://www.wine-searcher.com/find/barbaresco+...  $175.00
# 18  https://www.wine-searcher.com/find/barbaresco+...  $304.00
# 22  https://www.wine-searcher.com/find/barbaresco+...  $359.99
# 23  https://www.wine-searcher.com/find/barbaresco+...  $379.00
#
#              SELLER_INFORMATION                         OFFER_DESCRIPTION  \
# 2           The Redd Collection                1990Barbaresco,Angelo Gaja
# ...

# %%
USA.to_csv('filterCountry.csv')

# %%
USA['FIRST_MINIMUM_PRICE']=USA.loc[USA.groupby('SKU')['PRICE'].agg('min')];
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-98-df8c2c6e6770> in <module>
# ----> 1 USA['FIRST_MINIMUM_PRICE']=USA.loc[USA.groupby('SKU')['PRICE'].agg('min')];
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1498
#    1499             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1500             return self._getitem_axis(maybe_callable, axis=axis)
#    1501
#    1502     def _is_scalar_access(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1900                     raise ValueError('Cannot index with multidimensional key')
#    1901
# -> 1902                 return self._getitem_iterable(key, axis=axis)
#    1903
#    1904             # nested tuple slicing
#
# ...

# %%
USA.head()
# Out:
#       SKU                         DESCRIPTION  YEAR CAPACITY  \
# 2   11331              Barbaresco,Angelo Gaja  1990    750ml
# 6   11332              Barbaresco,Angelo Gaja  2010    750ml
# 18  11333  Barbaresco,Costa Russi,Angelo Gaja  2009    750ml
# 22  11333  Barbaresco,Costa Russi,Angelo Gaja  2009    750ml
# 23  11333  Barbaresco,Costa Russi,Angelo Gaja  2009    750ml
#
#                                                   URL  PRICE  \
# 2   https://www.wine-searcher.com/find/barbaresco+...  32900
# 6   https://www.wine-searcher.com/find/barbaresco+...  32900
# 18  https://www.wine-searcher.com/find/barbaresco+...  32900
# 22  https://www.wine-searcher.com/find/barbaresco+...  32900
# 23  https://www.wine-searcher.com/find/barbaresco+...  32900
#
#              SELLER_INFORMATION                         OFFER_DESCRIPTION  \
# 2           The Redd Collection                1990Barbaresco,Angelo Gaja
# 6           The Redd Collection                2010Barbaresco,Angelo Gaja
# ...

# %%
USA['PRICE']= USA.loc[USA['PRICE'].str.replace(',', '').str.replace('$', '').str.replace('.','').astype(int)]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-99-a3653e4d0d27> in <module>
# ----> 1 USA['PRICE']= USA.loc[USA['PRICE'].str.replace(',', '').str.replace('$', '').str.replace('.','').astype(int)]
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5061         if (name in self._internal_names_set or name in self._metadata or
#    5062                 name in self._accessors):
# -> 5063             return object.__getattribute__(self, name)
#    5064         else:
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~\Anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     169             # we're accessing the attribute of the class, i.e., Dataset.geo
#     170             return self._accessor
# --> 171         accessor_obj = self._accessor(obj)
# ...

# %%
USA.head()
# Out:
#       SKU                         DESCRIPTION  YEAR CAPACITY  \
# 2   11331              Barbaresco,Angelo Gaja  1990    750ml
# 6   11332              Barbaresco,Angelo Gaja  2010    750ml
# 18  11333  Barbaresco,Costa Russi,Angelo Gaja  2009    750ml
# 22  11333  Barbaresco,Costa Russi,Angelo Gaja  2009    750ml
# 23  11333  Barbaresco,Costa Russi,Angelo Gaja  2009    750ml
#
#                                                   URL  PRICE  \
# 2   https://www.wine-searcher.com/find/barbaresco+...  32900
# 6   https://www.wine-searcher.com/find/barbaresco+...  32900
# 18  https://www.wine-searcher.com/find/barbaresco+...  32900
# 22  https://www.wine-searcher.com/find/barbaresco+...  32900
# 23  https://www.wine-searcher.com/find/barbaresco+...  32900
#
#              SELLER_INFORMATION                         OFFER_DESCRIPTION  \
# 2           The Redd Collection                1990Barbaresco,Angelo Gaja
# 6           The Redd Collection                2010Barbaresco,Angelo Gaja
# ...
